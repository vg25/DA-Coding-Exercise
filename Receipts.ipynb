# %% [markdown]
# <a href="https://colab.research.google.com/github/vg25/DA-Coding-Exercise/blob/main/Receipts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing the necessary libraries
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import numpy as np

# %%
#Creating the dataframes and importing the json files:

df_receipts = pd.read_json('receipts.json', lines= True)

# %%
#Summary of data and to see the data type, memory usage, check if there are any missing values
df_receipts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   _id                      1119 non-null   object
#  1   bonusPointsEarned        544 non-null    float64
#  2   bonusPointsEarnedReason  544 non-null    object
#  3   createDate               1119 non-null   object
#  4   dateScanned              1119 non-null   object
#  5   finishedDate             568 non-null    object
#  6   modifyDate               1119 non-null   object
#  7   pointsAwardedDate        537 non-null    object
#  8   pointsEarned             609 non-null    float64
#  9   purchaseDate             671 non-null    object
#  10  purchasedItemCount       635 non-null    float64
#  11  rewardsReceiptItemList   679 non-null    object
#  12  rewardsReceiptStatus     1119 non-null   object
#  13  totalSpent               684 non-null    float64
# ...

# %% [markdown]
# There are in total 1119 rows and 15 columns. Columns like bonusPointsEarned, bonusPointsEarnedReason, finishedDate, pointsAwardedDate, purchaseDate, purchasedItemCount, rewardsReceiptItemList, totalSpent have missing data.

# %%
#display number of observations and features
df_receipts.shape
# Out:
# (1119, 15)

# %%
#display top 5 observation of the set
df_receipts.head()
# Out:
#                                     _id  bonusPointsEarned  \
# 0  {'$oid': '5ff1e1eb0a720f0523000575'}              500.0
# 1  {'$oid': '5ff1e1bb0a720f052300056b'}              150.0
# 2  {'$oid': '5ff1e1f10a720f052300057a'}                5.0
# 3  {'$oid': '5ff1e1ee0a7214ada100056f'}                5.0
# 4  {'$oid': '5ff1e1d20a7214ada1000561'}                5.0
#
#                              bonusPointsEarnedReason  \
# 0  Receipt number 2 completed, bonus point schedu...
# 1  Receipt number 5 completed, bonus point schedu...
# 2                         All-receipts receipt bonus
# 3                         All-receipts receipt bonus
# 4                         All-receipts receipt bonus
#
#                  createDate               dateScanned  \
# 0  {'$date': 1609687531000}  {'$date': 1609687531000}
# 1  {'$date': 1609687483000}  {'$date': 1609687483000}
# 2  {'$date': 1609687537000}  {'$date': 1609687537000}
# 3  {'$date': 1609687534000}  {'$date': 1609687534000}
# ...

# %%
#generate descriptive statistics
df_receipts.describe()
# Out:
#        bonusPointsEarned  pointsEarned  purchasedItemCount   totalSpent
# count         544.000000    609.000000           635.00000   684.000000
# mean          238.893382    585.962890            14.75748    77.796857
# std           299.091731   1357.166947            61.13424   347.110349
# min             5.000000      0.000000             0.00000     0.000000
# 25%             5.000000      5.000000             1.00000     1.000000
# 50%            45.000000    150.000000             2.00000    18.200000
# 75%           500.000000    750.000000             5.00000    34.960000
# max           750.000000  10199.800000           689.00000  4721.950000

# %%
#generate descriptive statistics and visualise using graph. Used the suggest chart feature of Google Colab
df_receipts.describe()
# Out:
#        bonusPointsEarned  pointsEarned  purchasedItemCount   totalSpent
# count         544.000000    609.000000           635.00000   684.000000
# mean          238.893382    585.962890            14.75748    77.796857
# std           299.091731   1357.166947            61.13424   347.110349
# min             5.000000      0.000000             0.00000     0.000000
# 25%             5.000000      5.000000             1.00000     1.000000
# 50%            45.000000    150.000000             2.00000    18.200000
# 75%           500.000000    750.000000             5.00000    34.960000
# max           750.000000  10199.800000           689.00000  4721.950000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
#number of missing records in each column
df_receipts.isnull().sum()
# Out:
# _id                          0
# bonusPointsEarned          575
# bonusPointsEarnedReason    575
# createDate                   0
# dateScanned                  0
# finishedDate               551
# modifyDate                   0
# pointsAwardedDate          582
# pointsEarned               510
# purchaseDate               448
# purchasedItemCount         484
# rewardsReceiptItemList     440
# rewardsReceiptStatus         0
# totalSpent                 435
# userId                       0
# dtype: int64

# %%
#calculate the percentage of missing values
(df_receipts.isnull().sum()/(len(df_receipts)))*100
# Out:
# _id                         0.000000
# bonusPointsEarned          51.385165
# bonusPointsEarnedReason    51.385165
# createDate                  0.000000
# dateScanned                 0.000000
# finishedDate               49.240393
# modifyDate                  0.000000
# pointsAwardedDate          52.010724
# pointsEarned               45.576408
# purchaseDate               40.035746
# purchasedItemCount         43.252904
# rewardsReceiptItemList     39.320822
# rewardsReceiptStatus        0.000000
# totalSpent                 38.873995
# userId                      0.000000
# dtype: float64

# %%
# Using data types
temporal_columns = df_receipts.select_dtypes(include=['datetime64'])

# Using heuristics (checking if column name contains "date" or "time")
temporal_columns = [col for col in df_receipts.columns if 'date' in col.lower() or 'time' in col.lower()]

print("Temporal Columns:")
print(temporal_columns)

categorical_columns = []
for col in df_receipts.columns:
    if isinstance(df_receipts[col][0], (str, bool)):
        categorical_columns.append(col)
print ("Categorical Columns are:")
print(categorical_columns)

# Exclude categorical and temporal columns
non_categorical_temporal_columns = [col for col in df_receipts.columns if col not in categorical_columns + temporal_columns]

# Identify continuous columns
continuous_columns = []
for col in non_categorical_temporal_columns:
    if isinstance(df_receipts[col][0], (int, float)):
        continuous_columns.append(col)

print("Continuous Columns:")
print(continuous_columns)

# Exclude categorical and temporal columns
non_categorical_temporal_columns = [col for col in df_receipts.columns if col not in categorical_columns + temporal_columns]

# Identify discrete columns
discrete_columns = []
for col in non_categorical_temporal_columns:
    if isinstance(df_receipts[col][0], int) and df_receipts[col].nunique() <= 10:
        discrete_columns.append(col)

print("Discrete Columns:")
print(discrete_columns)
# Out:
# Temporal Columns:
# ['createDate', 'dateScanned', 'finishedDate', 'modifyDate', 'pointsAwardedDate', 'purchaseDate']
# Categorical Columns are:
# ['bonusPointsEarnedReason', 'rewardsReceiptStatus', 'userId']
# Continuous Columns:
# ['bonusPointsEarned', 'pointsEarned', 'purchasedItemCount', 'totalSpent']
# Discrete Columns:
# []

# %%
#plot histogram to visualize
df_receipts.hist(figsize=(8,6))
plt.show()

# %%
#Boxplot to see the outliers
plt.figure()
sns.boxplot(data=df_receipts)
plt.show()

# %%
#To find Correlation if any
correlation_matrix = df_receipts.corr()
plt.figure()
sns.heatmap(correlation_matrix, annot=True)
plt.show()
# Out:
# <ipython-input-21-3fda75d92c75>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_receipts.corr()
